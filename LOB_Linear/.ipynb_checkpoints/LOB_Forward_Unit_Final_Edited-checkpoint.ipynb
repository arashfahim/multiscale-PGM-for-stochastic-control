# %%
import numpy as np
import time
from scipy import misc
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random
import math
import pandas as pd
#import cvxpy as cp
from scipy.optimize import fsolve

# %%
M=1000
ite=100
dim_n=3
T=1
delta = torch.tensor(T/ite)
#delta=torch.tensor(0.01)
sigma=0.2
mu=0.3
A0=0.0
gamma=0.0
kappa=1
rho=5
X0=10000
neuron_model_psi=50
print(delta)
# Out:
# tensor(0.0100)

# %%
model= torch.nn.Sequential(
    torch.nn.Linear(dim_n, neuron_model_psi),
    torch.nn.ReLU(),
    torch.nn.Linear(neuron_model_psi, neuron_model_psi),
    #torch.nn.ReLU(),
#     torch.nn.Linear(neuron_model_psi, neuron_model_psi),
    torch.nn.ReLU(),
    torch.nn.Linear(neuron_model_psi, neuron_model_psi),
    torch.nn.ReLU(),
    torch.nn.Linear(neuron_model_psi,1)
)

# %%
t=torch.zeros([M,1])
D=torch.zeros([M,1])
#D=torch.FloatTensor(M,1).uniform_(0.1,0.5)   #Price impact D_t
R=torch.FloatTensor(M,1).uniform_(X0*0.9,X0*1.1)   #remaining balance R_t   #To get a positive solution R_t has to be greater than D_t
x=torch.cat((t,D,R),dim=1)
# print(x)
# print(x.shape)

# %%
def update(x3,psi):
  t=(x3[:,0]+(1/ite))
  #print(psi.squeeze(1).shape,x1[:,1].shape)
  D = (x3[:,1]+kappa*psi)*torch.exp(-rho*delta)
  R= x3[:,2]-psi
  #print(R.shape)
  up=torch.cat((t.unsqueeze(1),D.unsqueeze(1),R.unsqueeze(1)),dim=1)
  #print('up shape=', up.shape)
  return up

def loss_func(x2,psi):
  loss=(x2[:,1]*psi+(kappa/2.0)*torch.pow(psi,2))
  return loss

def unit(x1,model):
    psi=model(x1).squeeze(1)
    los=loss_func(x1,psi)
    upd=update(x1,psi)
    #print('unit print=',psi.shape,los.shape,upd.shape)
    return psi,los,upd

def loss_func_total(u,model):
  loss=torch.zeros(M,ite)
  psi=torch.zeros(M,ite)
  for i in range(ite+1):
    if(i!=ite):
      psi_run,loss_run,u_run=unit(u,model)
      #print('los func=',psi_run.shape,loss_run.shape)
      loss[:,i]=loss_run
      #print(loss)
      psi[:,i]=psi_run
      #print(psi)
      u=u_run
      #print(u)
    else:
      #print(torch.sum(psi,dim=1),R.squeeze(1))
      psi_ter=R.squeeze(1)-torch.sum(psi,dim=1)
      loss_ter=loss_func(u,psi_ter)
      #print('ter',loss_ter.shape)
  #print(torch.sum(loss,dim=1))
  loss=torch.sum(loss,dim=1)+loss_ter
  #print(loss.shape)
  return torch.mean(loss)

# %% [markdown]
# Training

# %%
# start=time.time()
# lr1 = 8e-3
# epoch=0
# num_epochs=10000
# loss_epoch=[]
# L_=torch.tensor([-1000])
# optimizer = optim.Adam(model.parameters(), lr1)
# cost=torch.tensor([100000])
# err=1e-20
# #print(psi.shape)
# while (torch.abs(L_-cost)/torch.abs(L_)>err) &  (epoch <= num_epochs):
#   optimizer.zero_grad()
#   cost=loss_func_total(x,model)
#   cost.backward()
#   optimizer.step()
#   loss_epoch.append(cost)
#   if epoch>0:
#     L_ = loss_epoch[epoch-1]
#   #print(cost,L_.item())
#   if (epoch % 100==0):
#     print("At epoch {} the mean cost is {}.".format(epoch,cost.detach()))
#   if (torch.abs(L_-cost)/torch.abs(L_)<=err):
#     print("Delta Loss = {} , epoch = {}".format(torch.abs(L_-cost)/torch.abs(L_),epoch))
#   epoch=epoch+1

# end=time.time()
# print('time elapsed=',end-start)

# %%
start=time.time()
lr1 = 8e-3
max_epoch = 12000
optimizer = optim.Adam(model.parameters(), lr1)
cost_ar=[]
#print(psi.shape)
for epoch in range(max_epoch):
  optimizer.zero_grad()
  cost=loss_func_total(x,model)
  cost.backward()
  optimizer.step()
  cost_ar.append(cost)
  #print(loss.item())
  if (epoch % 100==0):
    print("At epoch {} the mean cost is {}.".format(epoch,cost.detach()))
end=time.time()
total_time=end-start
print('time elapsed=',total_time)
# Out:
# At epoch 0 the mean cost is 42289200.0.
# At epoch 100 the mean cost is 15014983.0.
# At epoch 200 the mean cost is 14835223.0.
# At epoch 300 the mean cost is 14705992.0.
# At epoch 400 the mean cost is 14808397.0.
# At epoch 500 the mean cost is 14627342.0.
# At epoch 600 the mean cost is 15172156.0.
# At epoch 700 the mean cost is 15076180.0.
# At epoch 800 the mean cost is 15022682.0.
# At epoch 900 the mean cost is 14781228.0.
# At epoch 1000 the mean cost is 14732986.0.
# At epoch 1100 the mean cost is 14696731.0.
# At epoch 1200 the mean cost is 14665461.0.
# At epoch 1300 the mean cost is 14639398.0.
# At epoch 1400 the mean cost is 14614524.0.
# At epoch 1500 the mean cost is 14595228.0.
# At epoch 1600 the mean cost is 14614016.0.
# At epoch 1700 the mean cost is 14594362.0.
# At epoch 1800 the mean cost is 14590494.0.
# At epoch 1900 the mean cost is 14585785.0.
# At epoch 2000 the mean cost is 14615408.0.
# At epoch 2100 the mean cost is 14578154.0.
# At epoch 2200 the mean cost is 14577142.0.
# At epoch 2300 the mean cost is 14576774.0.
# At epoch 2400 the mean cost is 14576669.0.
# At epoch 2500 the mean cost is 14576628.0.
# At epoch 2600 the mean cost is 14576613.0.
# At epoch 2700 the mean cost is 14576605.0.
# At epoch 2800 the mean cost is 14576603.0.
# At epoch 2900 the mean cost is 14576599.0.
# At epoch 3000 the mean cost is 14576596.0.
# At epoch 3100 the mean cost is 14947835.0.
# At epoch 3200 the mean cost is 14676470.0.
# At epoch 3300 the mean cost is 14622639.0.
# At epoch 3400 the mean cost is 14609748.0.
# At epoch 3500 the mean cost is 14600288.0.
# At epoch 3600 the mean cost is 14599921.0.
# At epoch 3700 the mean cost is 14592401.0.
# At epoch 3800 the mean cost is 14594853.0.
# At epoch 3900 the mean cost is 14590948.0.
# At epoch 4000 the mean cost is 14600552.0.
# At epoch 4100 the mean cost is 14605053.0.
# At epoch 4200 the mean cost is 14587754.0.
# At epoch 4300 the mean cost is 14588498.0.
# At epoch 4400 the mean cost is 14588447.0.
# At epoch 4500 the mean cost is 14590409.0.
# At epoch 4600 the mean cost is 14582597.0.
# At epoch 4700 the mean cost is 14580155.0.
# At epoch 4800 the mean cost is 14578584.0.
# At epoch 4900 the mean cost is 14577697.0.
# At epoch 5000 the mean cost is 14577226.0.
# At epoch 5100 the mean cost is 14576988.0.
# At epoch 5200 the mean cost is 14576872.0.
# At epoch 5300 the mean cost is 14576814.0.
# At epoch 5400 the mean cost is 14661718.0.
# At epoch 5500 the mean cost is 14728845.0.
# At epoch 5600 the mean cost is 14577649.0.
# At epoch 5700 the mean cost is 14576884.0.
# At epoch 5800 the mean cost is 14576736.0.
# At epoch 5900 the mean cost is 14576672.0.
# At epoch 6000 the mean cost is 14576636.0.
# At epoch 6100 the mean cost is 14576620.0.
# At epoch 6200 the mean cost is 14576610.0.
# At epoch 6300 the mean cost is 14576604.0.
# At epoch 6400 the mean cost is 14576603.0.
# At epoch 6500 the mean cost is 14576602.0.
# At epoch 6600 the mean cost is 14576601.0.
# At epoch 6700 the mean cost is 14576601.0.
# At epoch 6800 the mean cost is 14578469.0.
# At epoch 6900 the mean cost is 14576638.0.
# At epoch 7000 the mean cost is 14576602.0.
# At epoch 7100 the mean cost is 14576601.0.
# At epoch 7200 the mean cost is 14576599.0.
# At epoch 7300 the mean cost is 14576599.0.
# At epoch 7400 the mean cost is 14576599.0.
# At epoch 7500 the mean cost is 14576634.0.
# At epoch 7600 the mean cost is 14576596.0.
# At epoch 7700 the mean cost is 14576596.0.
# At epoch 7800 the mean cost is 14692269.0.
# At epoch 7900 the mean cost is 14576782.0.
# At epoch 8000 the mean cost is 14576628.0.
# At epoch 8100 the mean cost is 14576609.0.
# At epoch 8200 the mean cost is 14576603.0.
# At epoch 8300 the mean cost is 14576599.0.
# At epoch 8400 the mean cost is 14576597.0.
# At epoch 8500 the mean cost is 14576597.0.
# At epoch 8600 the mean cost is 14576597.0.
# At epoch 8700 the mean cost is 14636325.0.
# At epoch 8800 the mean cost is 14577551.0.
# At epoch 8900 the mean cost is 14576941.0.
# At epoch 9000 the mean cost is 14576743.0.
# At epoch 9100 the mean cost is 14576660.0.
# At epoch 9200 the mean cost is 14576624.0.
# At epoch 9300 the mean cost is 14576607.0.
# At epoch 9400 the mean cost is 14576603.0.
# At epoch 9500 the mean cost is 14576599.0.
# At epoch 9600 the mean cost is 14576597.0.
# At epoch 9700 the mean cost is 14576599.0.
# At epoch 9800 the mean cost is 14595603.0.
# At epoch 9900 the mean cost is 14576609.0.
# At epoch 10000 the mean cost is 14576601.0.
# At epoch 10100 the mean cost is 14576599.0.
# At epoch 10200 the mean cost is 14576597.0.
# At epoch 10300 the mean cost is 14576599.0.
# At epoch 10400 the mean cost is 14576788.0.
# At epoch 10500 the mean cost is 14576601.0.
# At epoch 10600 the mean cost is 14576593.0.
# At epoch 10700 the mean cost is 14576591.0.
# At epoch 10800 the mean cost is 14576591.0.
# At epoch 10900 the mean cost is 14576591.0.
# At epoch 11000 the mean cost is 14608382.0.
# At epoch 11100 the mean cost is 14576727.0.
# At epoch 11200 the mean cost is 14576642.0.
# At epoch 11300 the mean cost is 14576611.0.
# At epoch 11400 the mean cost is 14576599.0.
# At epoch 11500 the mean cost is 14576595.0.
# At epoch 11600 the mean cost is 14576595.0.
# At epoch 11700 the mean cost is 14576595.0.
# At epoch 11800 the mean cost is 14576595.0.
# At epoch 11900 the mean cost is 14576595.0.
# time elapsed= 41.89468479156494

# %%
# #time step vs training time plot
# x=np.array([10,30,50,100]) #time steps
# y=np.array([119,440,677,1356])#training times
# plt.plot(x,y)
# plt.show()

# %% [markdown]
# Solution by using cvxpy package

# %%
def numeric_soln(X,n):
    delt=T/n
    alpa=math.exp(-delt*rho)
    c=np.ones(n)
    x=cp.Variable(n)
    #objective=cp.Minimize(determinstic_main(x))
    A=[[0 for i in range(n)] for j in range(n)]
    for i in range(n):
        for j in range(n):
            A[i][j]=1-kappa+kappa*pow(alpa,abs(i-j))
    constraints=[0<=x,sum(x)==X]

    objective=cp.Minimize(1/2*cp.quad_form(x,A))
    prob=cp.Problem(objective,constraints)
    #print("prob is DCP:", prob.is_dcp())
    #print("curvature of objective:",cp.sum(pow(x,2)).curvature)
    #assert prob.is_dqcp()
    cost=prob.solve()
    #print("Optimal value", prob.solve())
    #print("Optimal value", prob.solve(qcp=True))
    #print("Optimal soln")
    soln=x.value
    #print(soln) # A numpy ndarray
    return soln,cost

# %% [markdown]
# Colsed form soln

# %%
def closed_form(X):
  alpa=np.exp(-rho*T/ite)
  p=np.zeros(ite+1)
  p[0]=X/((ite-1)*(1-alpa)+2)
  p[ite]=X/((ite-1)*(1-alpa)+2)
  for j in range(1,ite):
    p[j]=p[0]*(1-alpa)
  return p

# %% [markdown]
# **Calculating cost** predicted and closed cost both have the same function. I wrote it twice because of two different data type

# %%
def cost(y):
  cost1=0.0
  D1=0.0
  for i in range(ite+1):
    cost1+=D1*y[i]+(kappa/2.0)*np.power(y[i],2)
    D1=(D1+kappa*y[i])*np.exp(-rho*T/ite)
  return cost1

# %%
model=torch.load('model_N100_T1_K1_rho5_neo50.pth')

# %% [markdown]
# **Testing ** We have compared the closed form solution from Obhizaeva and Wang, our predicted solution and the solution from python convex optimization package cvxpy

# %%
from torch.nn.modules.pooling import MaxPool1d
M1=20
t_test=torch.zeros([M1,1])
D_test=torch.zeros([M1,1])
#D_test=torch.FloatTensor(M,1).uniform_(0.1,0.5)   #Price impact D_t
#R_test=torch.FloatTensor(M1,1).uniform_(50,100)   #remaining balance R_t   #To get a positive solution R_t has to be greater than D_t
R_test=torch.linspace(X0*0.95, X0*1.05, steps=M1).unsqueeze(1)
x_test=torch.cat((t_test,D_test,R_test),dim=1)
#print('Input=',x_test,'\n')
a=torch.zeros(M1,ite+1)
#print(a.shape)
for i in range(ite+1):
  if(i!=ite):
    #print(x_test)
    soln_pred=model(x_test).squeeze(1).detach()
    a[:,i]=soln_pred
    x_test=update(x_test,soln_pred)
    #print(x_test,'\n')
  else:
    a[:,i]=R_test.squeeze(1)-torch.sum(a,dim=1)

x1=R_test.squeeze().numpy()
c_true=np.zeros(M1)
c_pred=np.zeros(M1)
c_num=np.zeros(M1)
n_soln=np.zeros((M1,ite+1))
t_soln=np.zeros((M1,ite+1))

for i in range(M1):
  print('size of total order=',x1[i])

  t_soln[i,:]=closed_form(x1[i])
  print('closed form soln=',t_soln[i,:],'sum of all execution=',np.sum(t_soln[i,:]))
  true_cost=cost(t_soln[i,:])
  c_true[i]=true_cost
  print('Closed form cost=',true_cost,'\n')

  print('predicted soln=',a[i,:],'sum of all execution=',torch.sum(a[i,:]).detach())
  pred_cost=cost(a[i,:].detach().numpy())
  print('predicted cost=',pred_cost,'\n')
  c_pred[i]=pred_cost
  print('Percent Error in cost=',np.abs(100*(true_cost-pred_cost)/true_cost),'%\n')
# Out:
# size of total order= 9500.0
# closed form soln= [1391.27134457   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#    67.85310415   67.85310415   67.85310415   67.85310415   67.85310415
#  1391.27134457] sum of all execution= 9500.0
# Closed form cost= 12894775.528668163
#
# predicted soln= tensor([1323.7255,  115.6693,   77.9172,   75.4019,   73.1674,   71.1756,
#           69.3939,   67.9964,   67.9817,   67.9672,   67.9531,   67.9392,
#           67.9256,   67.9122,   67.8991,   67.8862,   67.8736,   67.8613,
#           67.8493,   67.8374,   67.8259,   67.8146,   67.8036,   67.7928,
#           67.7823,   67.7721,   67.7621,   67.7523,   67.7429,   67.7336,
#           67.7247,   67.7160,   67.7075,   67.6993,   67.6914,   67.6837,
#           67.6762,   67.6691,   67.6621,   67.6555,   67.6491,   67.6434,
#           67.6405,   67.6380,   67.6359,   67.6341,   67.6328,   67.6319,
#           67.6313,   67.6312,   67.6314,   67.6321,   67.6331,   67.6345,
#           67.6363,   67.6385,   67.6412,   67.6441,   67.6475,   67.6443,
#           67.6324,   67.6200,   67.6074,   67.5944,   67.5810,   67.5673,
#           67.5569,   67.5476,   67.5382,   67.5286,   67.5190,   67.5092,
#           67.5131,   67.5376,   67.5635,   67.5910,   67.6200,   67.6505,
#           67.6753,   67.6948,   67.7152,   67.7364,   67.7488,   67.7556,
#           67.7625,   67.7686,   67.7647,   67.7619,   67.7592,   67.7561,
#           67.7527,   67.7415,   67.7226,   67.7028,   67.6820,   67.6503,
#           67.4902,   64.4009,   60.9544,   27.8255, 1447.1484]) sum of all execution= tensor(9500.)
# predicted cost= 12895268.817672618
#
# Percent Error in cost= 0.0038254950879733425 %
#
# size of total order= 9552.632
# closed form soln= [1398.97925669   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#    68.22902346   68.22902346   68.22902346   68.22902346   68.22902346
#  1398.97925669] sum of all execution= 9552.631835937502
# Closed form cost= 13038050.414430663
#
# predicted soln= tensor([1331.0477,  116.3017,   78.3396,   75.8111,   73.5648,   71.5627,
#           69.7716,   68.3614,   68.3461,   68.3312,   68.3165,   68.3021,
#           68.2879,   68.2740,   68.2604,   68.2471,   68.2340,   68.2211,
#           68.2085,   68.1962,   68.1842,   68.1724,   68.1609,   68.1496,
#           68.1386,   68.1278,   68.1173,   68.1071,   68.0971,   68.0874,
#           68.0779,   68.0687,   68.0598,   68.0511,   68.0427,   68.0345,
#           68.0266,   68.0189,   68.0115,   68.0043,   67.9975,   67.9912,
#           67.9878,   67.9849,   67.9823,   67.9801,   67.9783,   67.9769,
#           71.7161,   71.7184,   71.7184,   71.7066,   71.6989,   71.6909,
#           71.6826,   71.6739,   71.6514,   71.6262,   71.5999,   71.5725,
#           71.5271,   70.2086,   66.9803,   57.0613, 1546.9619]) sum of all execution= tensor(10131.5791)
# predicted cost= 14667509.644073445
#
# Percent Error in cost= 0.008180877258562726 %
#
# size of total order= 10184.211
# closed form soln= [1491.47377309   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#    72.74003426   72.74003426   72.74003426   72.74003426   72.74003426
#  1491.47377309] sum of all execution= 10184.210937499998
# Closed form cost= 14819083.586676713
#
# predicted soln= tensor([1418.9171,  123.8886,   83.4075,   80.7214,   78.3348,   76.2074,
#           74.3041,   72.7413,   72.7198,   72.6985,   72.6775,   72.6568,
#           72.6364,   72.6162,   72.5964,   72.5768,   72.5575,   72.5385,
#           72.5198,   72.5013,   72.4832,   72.4653,   72.4477,   72.4304,
#           72.4133,   72.3965,   72.3800,   72.3638,   72.3479,   72.3322,
#           72.3168,   72.3017,   72.2869,   72.2723,   72.2580,   72.2440,
#           72.2303,   72.2168,   72.2036,   72.1907,   72.1781,   72.1657,
#           72.1559,   72.1474,   72.1392,   72.1315,   72.1242,   72.1173,
#           72.1109,   72.1049,   72.0993,   72.0941,   72.0893,   72.0849,
#           72.0810,   72.0775,   72.0744,   72.0717,   72.0695,   72.0686,
#           72.0507,   72.0322,   72.0134,   71.9942,   71.9746,   71.9546,
#           71.9348,   71.9193,   71.9038,   71.8881,   71.8724,   71.8564,
#           71.8404,   71.8545,   71.8755,   71.8981,   71.9223,   71.9482,
#           71.9756,   71.9918,   72.0073,   72.0238,   72.0411,   72.0438,
#           72.0456,   72.0475,   72.0473,   72.0353,   72.0272,   72.0188,
#           72.0100,   72.0009,   71.9787,   71.9530,   71.9263,   71.8984,
#           71.8536,   70.6931,   67.4429,   59.0008, 1555.8301]) sum of all execution= tensor(10184.2119)
# predicted cost= 14820390.344124954
#
# Percent Error in cost= 0.00881807191786118 %
#
# size of total order= 10236.842
# closed form soln= [1499.1815422    73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#    73.11594659   73.11594659   73.11594659   73.11594659   73.11594659
#  1499.1815422 ] sum of all execution= 10236.841796874998
# Closed form cost= 14972646.083206147
#
# predicted soln= tensor([1426.2395,  124.5208,   83.8299,   81.1306,   78.7324,   76.5945,
#           74.6818,   73.1063,   73.0842,   73.0624,   73.0409,   73.0197,
#           72.9988,   72.9781,   72.9577,   72.9376,   72.9178,   72.8983,
#           72.8791,   72.8601,   72.8414,   72.8230,   72.8049,   72.7871,
#           72.7695,   72.7523,   72.7353,   72.7185,   72.7021,   72.6859,
#           72.6701,   72.6545,   72.6391,   72.6241,   72.6093,   72.5948,
#           72.5806,   72.5666,   72.5530,   72.5396,   72.5265,   72.5136,
#           72.5033,   72.4943,   72.4857,   72.4775,   72.4697,   72.4624,
#           72.4555,   72.4490,   72.4429,   72.4373,   72.4321,   72.4273,
#           72.4229,   72.4190,   72.4154,   72.4123,   72.4096,   72.4081,
#           72.3905,   72.3716,   72.3523,   72.3326,   72.3125,   72.2921,
#           73.9818,   73.9659,   73.9503,   73.9350,   73.9200,   73.9052,
#           73.8926,   73.8818,   73.8713,   73.8613,   73.8517,   73.8426,
#           73.8338,   73.8255,   73.8177,   73.8102,   73.8032,   73.7967,
#           73.7905,   73.7848,   73.7795,   73.7747,   73.7702,   73.7662,
#           73.7499,   73.7290,   73.7078,   73.6862,   73.6642,   73.6419,
#           73.6191,   73.6007,   73.5828,   73.5648,   73.5466,   73.5283,
#           73.5099,   73.5149,   73.5340,   73.5547,   73.5771,   73.6012,
#           73.6269,   73.6444,   73.6581,   73.6727,   73.6882,   73.6929,
#           73.6927,   73.6926,   73.6913,   73.6785,   73.6684,   73.6579,
#           73.6470,   73.6358,   73.6152,   73.5872,   73.5582,   73.5280,
#           73.4855,   73.1021,   69.7562,   65.2167, 1603.6650]) sum of all execution= tensor(10447.3682)
# predicted cost= 15596788.50660232
#
# Percent Error in cost= 0.012620899695794593 %
#
# size of total order= 10500.0
# closed form soln= [1537.72095978   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#    74.99553617   74.99553617   74.99553617   74.99553617   74.99553617
#  1537.72095978] sum of all execution= 10499.999999999996
# Closed form cost= 15752343.51286057
#
# predicted soln= tensor([1462.8518,  127.6820,   85.9415,   83.1765,   80.7199,   78.5298,
#           76.5704,   74.9313,   74.9066,   74.8822,   74.8580,   74.8342,
#           74.8106,   74.7874,   74.7644,   74.7417,   74.7193,   74.6972,
#           74.6754,   74.6539,   74.6327,   74.6118,   74.5911,   74.5708,
#           74.5507,   74.5309,   74.5114,   74.4922,   74.4733,   74.4546,
#           74.4363,   74.4182,   74.4004,   74.3829,   74.3657,   74.3488,
#           74.3322,   74.3158,   74.2997,   74.2839,   74.2684,   74.2532,
#           74.2400,   74.2286,   74.2177,   74.2073,   74.1972,   74.1876,
#           74.1784,   74.1697,   74.1614,   74.1535,   74.1461,   74.1390,
#           74.1325,   74.1263,   74.1206,   74.1153,   74.1105,   74.1060,
#           74.0898,   74.0685,   74.0468,   74.0247,   74.0022,   73.9794,
#           73.9562,   73.9370,   73.9186,   73.9001,   73.8815,   73.8627,
#           73.8439,   73.8471,   73.8658,   73.8862,   73.9082,   73.9319,
#           73.9572,   73.9750,   73.9883,   74.0026,   74.0177,   74.0227,
#           74.0222,   74.0217,   74.0201,   74.0072,   73.9967,   73.9857,
#           73.9745,   73.9629,   73.9426,   73.9141,   73.8846,   73.8540,
#           73.8120,   73.5837,   70.2186,   66.4583, 1613.2295]) sum of all execution= tensor(10500.)
# predicted cost= 15754462.664835079
#
# Percent Error in cost= 0.013452931449713594 %

# %% [markdown]
# Comparing the cost

# %%
# print(x1.shape)
# name='E:/Robin research/ECMF_poster/N50.eps'
# plt.figure()
# plt.plot(x1,c_true,color='blue',label='cost_true',marker='1')
# plt.plot(x1,c_pred,color='red',label='cost_predicted')
# plt.plot(x1,c_num,color='green',label='cost_numeric')
# plt.legend()
# plt.savefig(name,format='eps')
# plt.show()

# %% [markdown]
# Comparing solution for diffeternt testing samples

# %%
p_soln=a.numpy()
t_step=np.linspace(0,ite,num=ite+1)
name='/Users/shirinprovat/Desktop/Robin_Research/LOB_Linear/N_100_Linear.eps'
def plotting(t):
  #print('Total order size=',x1[t],np.sum(n_soln[t]),np.sum(p_soln[t]))
  #print(n_soln[t],p_soln[t])
  plt.figure(figsize=(6,3))
  plt.bar(t_step,t_soln[t],color='blue',width=0.3,label='Closed-Form')
  plt.bar(t_step,p_soln[t],color='red',width=0.2,label='DNN')
  #plt.bar(t_step,n_soln[t],color='green',width=0.1,label='numeric')
  plt.title('Total Order size X= %i' % (x1[t]))
  plt.xlabel('Time steps')
  plt.ylabel('Optimal orders')
  plt.legend()

  #plt.savefig('f.eps', format='eps')
  if(t==0):
    plt.savefig(name,format='eps')      
  plt.show()
for i in range(0,M1,3):
  plotting(i)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#torch.save(model, 'model_N10_T10_K1_rho.5_neo20.pth') 
#model_coarse = torch.load('model_N10.pth')

# %%
# import json
# cost_numpy_list = [tensor.detach().item() for tensor in cost_ar]
# my_dic = {'Num_sample':M,'Time_step':ite,'T':T,'kappa':kappa,'Rho':rho,'Total_balance':X0,
#         'Num_neoron':neuron_model_psi,'Training_time':total_time,'epoch':max_epoch,
#           'accuracy':0.00001*1/100,'Training_cost':cost_numpy_list}

# file_path=  'N_10_linear_dic.json'
# with open(file_path,'w') as file:
#     json.dump(my_dic,file)

# %% [markdown]
# Comparing solution at different time steps

# %%
#p_soln=a.numpy()
t_step=np.linspace(0,ite,num=ite+1)
X=R_test.squeeze(1).numpy()
def plotting_time(t):
  #print(t_soln[t],p_soln[t])
  plt.figure(figsize=(4,2))
  plt.plot(X,t_soln[:,0],color='blue',label='true')
  plt.plot(X,p_soln[:,0],color='red',label='pred')
  plt.plot(X,n_soln[:,0],color='green',label='numeric')
  plt.title('At time= %d' % (t_step[t]))
  plt.xlabel('Total Order size')
  plt.ylabel('Optimal orders')
  plt.legend()
  plt.show
for i in range(0,t_step.shape[0],5):
  plotting_time(i)

# %% [markdown]
# Absolute sum of the difference between true solution, predicted solution and true soln, numeric soln at each time step

# %%
sq_error=np.zeros(M1)
sq_error_num=np.zeros(M1)

for i in range(M1):
  sq_error[i]=np.sum(np.abs(t_soln[i]-p_soln[i]))
  sq_error_num[i]=np.sum(np.abs(t_soln[i]-n_soln[i]))
  print(np.sum(t_soln[i]),'    ',sq_error[i])

plt.figure(figsize=(4,2))
plt.plot(X,sq_error,color='blue',label='pred')
#plt.plot(X,sq_error_num,color='green',label='numeric')
plt.title('Error with sample size= %d' % (M1))
plt.xlabel('Total Order size')
plt.ylabel('Sum of execution error')
plt.legend()
# Out:
# 9500.0      15.395684430878418
# 9552.6318359375      14.225892477605385
# 9605.262695312498      13.072270932041306
# 9657.89453125      11.922697200649282
# 9710.5263671875      10.852167538585604
# 9763.158203124998      9.80645406146914
# 9815.7890625      8.760582403661942
# 9868.420898437498      7.796761321869326
# 9921.052734375      6.887806048247171
# 9973.6845703125      5.987848566562434
# 10026.315429687498      5.18221631394033
# 10078.947265625      4.474844144494796
# 10131.579101562498      3.7689368187985792
# 10184.2109375      3.763732714500293
# 10236.841796875      4.440542766029694
# 10289.4736328125      5.163829094339349
# 10342.10546875      5.933318924196669
# 10394.7373046875      6.885221366157225
# 10447.368164062498      7.837831305214422
# 10500.0      8.855020926280645

# %% [markdown]
# Additional rough test

# %%
# from torch.nn.modules.pooling import MaxPool1d
# M1=100
# t_test=torch.zeros([M1,1])
# D_test=torch.zeros([M1,1])
# #D_test=torch.FloatTensor(M,1).uniform_(0.1,0.5)   #Price impact D_t
# R_test=torch.linspace(50,100,100).unsqueeze(1)   #remaining balance R_t   #To get a positive solution R_t has to be greater than D_t
# x_test=torch.cat((t_test,D_test,R_test),dim=1)
# #print('Input=',x_test,'\n')
# soln=[]
# x_update = x_test
# #print(x_update)
# for i in range(ite+1):
#     #print(x_update)
#     soln_pred=model(x_update)
#     #print(soln_pred)
#     x_udpate=update(x_update,soln_pred.squeeze(1))
#     #print(x_update)
#     soln.append(soln_pred)
# strategy = torch.cat(soln,dim=1)
# print(strategy)
# # print('predicted soln=',strategy,'sum of all execution=',torch.sum(strategy,dim=1),'\n')
# a=[]
# b=[]
# c=[]
# for x in R_test:
#     a.append(x.numpy()[0])
#     y=closed_form(x.numpy()[0],ite+1)
#     #print(y)
#     b.append(y[0][0])
#     c.append(y[1])

# %%
#model= torch.load('model_N10.pth')

# %%
# from torch.nn.modules.pooling #model= torch.load('model_N10.pth')import MaxPool1d
# M1=20
# t_test=torch.zeros([M1,1])
# D_test=torch.zeros([M1,1])
# #D_test=torch.FloatTensor(M,1).uniform_(0.1,0.5)   #Price impact D_t
# #R_test=torch.FloatTensor(M1,1).uniform_(50,100)   #remaining balance R_t   #To get a positive solution R_t has to be greater than D_t
# R_test=torch.linspace(X0*0.95, X0*1.05, steps=M1).unsqueeze(1)
# x_test=torch.cat((t_test,D_test,R_test),dim=1)
# #print('Input=',x_test,'\n')
# a=torch.zeros(M1,ite+1)
# #print(a.shape)
# for i in range(ite+1):
#   if(i!=ite):
#     #print(x_test)
#     soln_pred=model(x_test).squeeze(1).detach()
#     a[:,i]=soln_pred
#     x_test=update(x_test,soln_pred)
#     #print(x_test,'\n')
#   else:
#     a[:,i]=R_test.squeeze(1)-torch.sum(a,dim=1)

# x1=R_test.squeeze().numpy()
# c_true=np.zeros(M1)
# c_pred=np.zeros(M1)
# c_num=np.zeros(M1)
# n_soln=np.zeros((M1,ite+1))
# t_soln=np.zeros((M1,ite+1))

# for i in range(M1):
#   print('size of total order=',x1[i])

#   t_soln[i,:]=closed_form(x1[i])
#   print('closed form soln=',t_soln[i,:],'sum of all execution=',np.sum(t_soln[i,:]))
#   true_cost=cost(t_soln[i,:])
#   c_true[i]=true_cost
#   print('Closed form cost=',true_cost,'\n')

#   print('predicted soln=',a[i,:],'sum of all execution=',torch.sum(a[i,:]).detach())
#   pred_cost=cost(a[i,:].detach().numpy())
#   print('predicted cost=',pred_cost,'\n')
#   c_pred[i]=pred_cost
#   print('Percent Error in cost=',np.abs(100*(true_cost-pred_cost)/true_cost),'%\n')
