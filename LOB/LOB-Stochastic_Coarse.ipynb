# %%
import numpy as np
import time
from scipy import misc
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random
import math
import pandas as pd
from scipy.optimize import fsolve

# %%
M=2000
ite=10
dim_n=5
T=1
delta = torch.tensor(T/ite)
#delta=torch.tensor(0.01)
sigma=0.1
sigma1=1e-3
sigma2=1e-2
theta1=1
theta2=1
mu1=1e-2 #kappa
mu2=5 #rho
A0=0.0
gamma=0.0
X0=10000
neuron_model_psi=20
print(delta)
# Out:
# tensor(0.1000)

# %%
model= torch.nn.Sequential(
    torch.nn.Linear(dim_n, neuron_model_psi),
    torch.nn.ReLU(),
#     torch.nn.Linear(neuron_model_psi, neuron_model_psi),
#     torch.nn.ReLU(),
#     torch.nn.Linear(neuron_model_psi, neuron_model_psi),
#     torch.nn.ReLU(),   torch.nn.ReLU(),
#   
    torch.nn.Linear(neuron_model_psi, neuron_model_psi),
    torch.nn.ReLU(),
    torch.nn.Linear(neuron_model_psi,1)
)

# %%
def kappa_rho_sim(M,ite,theta1,mu1,sigma1,theta2,mu2,sigma2):
    kappa=torch.zeros([M,ite+1])
    kappa[:,0]=mu1
    rho=torch.zeros([M,ite+1])
    rho[:,0]=mu2

    for i in range (1,ite+1):
        kappa[:,i]=kappa[:,i-1]+theta1*(mu1-kappa[:,i-1])*delta+np.sqrt(delta)*sigma1*np.random.rand(M)  # Xn+1=Xn+θ(μ−Xn)Δt+σΔWn
        rho[:,i]=rho[:,i-1]+theta2*(mu2-rho[:,i-1])*delta+np.sqrt(delta)*sigma2*np.random.rand(M)
    return kappa,rho

# %%
t=torch.zeros([M,1])
D=torch.zeros([M,1])
kappa,rho=kappa_rho_sim(M,ite,theta1,mu1,sigma1,theta2,mu2,sigma2)
R=torch.FloatTensor(M,1).uniform_(X0*0.9,X0*1.1)   #remaining balance R_t   #To get a positive solution R_t has to be greater than D_t

# %%
print('kappa=',kappa,'\n rho=',rho) 
x=torch.cat((t,D,R,kappa[:,0].unsqueeze(1),rho[:,0].unsqueeze(1)),dim=1)
# Out:
# kappa= tensor([[0.0100, 0.0101, 0.0103,  ..., 0.0110, 0.0109, 0.0111],
#         [0.0100, 0.0100, 0.0100,  ..., 0.0106, 0.0106, 0.0106],
#         [0.0100, 0.0103, 0.0104,  ..., 0.0106, 0.0107, 0.0107],
#         ...,
#         [0.0100, 0.0101, 0.0103,  ..., 0.0106, 0.0106, 0.0107],
#         [0.0100, 0.0103, 0.0104,  ..., 0.0111, 0.0110, 0.0111],
#         [0.0100, 0.0101, 0.0102,  ..., 0.0106, 0.0106, 0.0106]])
#  rho= tensor([[5.0000, 5.0007, 5.0019,  ..., 5.0069, 5.0086, 5.0097],
#         [5.0000, 5.0012, 5.0013,  ..., 5.0080, 5.0085, 5.0086],
#         [5.0000, 5.0020, 5.0026,  ..., 5.0090, 5.0098, 5.0100],
#         ...,
#         [5.0000, 5.0002, 5.0018,  ..., 5.0080, 5.0104, 5.0103],
#         [5.0000, 5.0002, 5.0004,  ..., 5.0060, 5.0069, 5.0063],
#         [5.0000, 5.0011, 5.0024,  ..., 5.0082, 5.0077, 5.0089]])

# %%
if (rho >0).all():
    print('true')
# Out:
# true

# %%
def update(x3,psi,i):
  t=(x3[:,0]+(1/ite))
  kap=kappa[:,i+1]
  rh=rho[:,i+1]
#   kappa=x3[:,3]+theta1*(mu1-x3[:,3])*delta+torch.sqrt(delta)*sigma1*W1[i]
#   rho=x3[:,4]+theta2*(mu2-x3[:,4])*delta+torch.sqrt(delta)*sigma1*W2[i]
  D = (x3[:,1]+kap*psi)*torch.exp(-rh*delta)
  #print('d',D.shape)
  R= x3[:,2]-psi
  #print(kappa.shape,rho.shape)
  up=torch.cat((t.unsqueeze(1),D.unsqueeze(1),R.unsqueeze(1),kap.unsqueeze(1),rh.unsqueeze(1)),dim=1)
  return up

def loss_func(x2,psi):
  loss=(x2[:,1]*psi+(x2[:,3]/2.0)*torch.pow(psi,2))
  #print('loss',loss.shape)
  return loss

def unit(x1,model,i):
    psi=model(x1).squeeze(1)
    los=loss_func(x1,psi)
    upd=update(x1,psi,i)
    #print(upd)
    return psi,los,upd

def loss_func_total(u,model):
  loss=torch.zeros(M,ite)
  psi=torch.zeros(M,ite)
  for i in range(ite+1):
    if(i!=ite):
      psi_run,loss_run,u_run=unit(u,model,i)
      #print('los func=',psi_run.shape,loss_run.shape)
      loss[:,i]=loss_run
      #print(loss)
      psi[:,i]=psi_run
      #print(psi)
      u=u_run
      #print(u)
    else:
      #print(torch.sum(psi,dim=1),R.squeeze(1))
      psi_ter=R.squeeze(1)-torch.sum(psi,dim=1)
      loss_ter=loss_func(u,psi_ter)
      #print('ter',loss_ter.shape)
  #print(torch.sum(loss,dim=1))
  loss=torch.sum(loss,dim=1)+loss_ter
  #print(loss.shape)
  return torch.mean(loss)

# %%
start=time.time()
lr1 = 8e-3
max_epoch = 15000
optimizer = optim.Adam(model.parameters(), lr1)

#print(psi.shape)
for epoch in range(max_epoch):
  optimizer.zero_grad()
  cost=loss_func_total(x,model)
  cost.backward()
  optimizer.step()
  #print(loss.item())
  if (epoch % 100==0):
    print("At epoch {} the mean cost is {}.".format(epoch,cost.detach()))
end=time.time()
print('time elapsed=',end-start)
# Out:
# At epoch 0 the mean cost is 630321.25.
# At epoch 100 the mean cost is 158411.875.
# At epoch 200 the mean cost is 158399.140625.
# At epoch 300 the mean cost is 158385.734375.
# At epoch 400 the mean cost is 158370.09375.
# At epoch 500 the mean cost is 158352.515625.
# At epoch 600 the mean cost is 158333.125.
# At epoch 700 the mean cost is 158311.84375.
# At epoch 800 the mean cost is 158288.515625.
# At epoch 900 the mean cost is 158262.8125.
# At epoch 1000 the mean cost is 158234.171875.
# At epoch 1100 the mean cost is 158201.796875.
# At epoch 1200 the mean cost is 158164.359375.
# At epoch 1300 the mean cost is 158119.890625.
# At epoch 1400 the mean cost is 158065.40625.
# At epoch 1500 the mean cost is 157996.765625.
# At epoch 1600 the mean cost is 157908.4375.
# At epoch 1700 the mean cost is 157796.953125.
# At epoch 1800 the mean cost is 157545.359375.
# At epoch 1900 the mean cost is 157276.9375.
# At epoch 2000 the mean cost is 156831.203125.
# At epoch 2100 the mean cost is 156501.015625.
# At epoch 2200 the mean cost is 156257.15625.
# At epoch 2300 the mean cost is 156032.1875.
# At epoch 2400 the mean cost is 156004.359375.
# At epoch 2500 the mean cost is 155694.25.
# At epoch 2600 the mean cost is 155480.53125.
# At epoch 2700 the mean cost is 155752.1875.
# At epoch 2800 the mean cost is 155113.03125.
# At epoch 2900 the mean cost is 155085.953125.
# At epoch 3000 the mean cost is 154858.34375.
# At epoch 3100 the mean cost is 154887.234375.
# At epoch 3200 the mean cost is 154596.609375.
# At epoch 3300 the mean cost is 154532.609375.
# At epoch 3400 the mean cost is 154457.25.
# At epoch 3500 the mean cost is 154399.28125.
# At epoch 3600 the mean cost is 154606.546875.
# At epoch 3700 the mean cost is 154372.921875.
# At epoch 3800 the mean cost is 154348.015625.
# At epoch 3900 the mean cost is 154311.171875.
# At epoch 4000 the mean cost is 154328.703125.
# At epoch 4100 the mean cost is 154282.875.
# At epoch 4200 the mean cost is 154258.75.
# At epoch 4300 the mean cost is 154253.796875.
# At epoch 4400 the mean cost is 154258.09375.
# At epoch 4500 the mean cost is 154555.21875.
# At epoch 4600 the mean cost is 154249.140625.
# At epoch 4700 the mean cost is 154243.71875.
# At epoch 4800 the mean cost is 154315.90625.
# At epoch 4900 the mean cost is 154236.65625.
# At epoch 5000 the mean cost is 154235.28125.
# At epoch 5100 the mean cost is 154285.03125.
# At epoch 5200 the mean cost is 154258.46875.
# At epoch 5300 the mean cost is 154311.9375.
# At epoch 5400 the mean cost is 154373.84375.
# At epoch 5500 the mean cost is 154242.25.
# At epoch 5600 the mean cost is 154221.984375.
# At epoch 5700 the mean cost is 154218.4375.
# At epoch 5800 the mean cost is 154237.484375.
# At epoch 5900 the mean cost is 154229.5.
# At epoch 6000 the mean cost is 154265.390625.
# At epoch 6100 the mean cost is 154303.640625.
# At epoch 6200 the mean cost is 154334.671875.
# At epoch 6300 the mean cost is 154207.515625.
# At epoch 6400 the mean cost is 154207.4375.
# At epoch 6500 the mean cost is 154229.421875.
# At epoch 6600 the mean cost is 154219.875.
# At epoch 6700 the mean cost is 154240.59375.
# At epoch 6800 the mean cost is 154277.84375.
# At epoch 6900 the mean cost is 154206.65625.
# At epoch 7000 the mean cost is 154193.6875.
# At epoch 7100 the mean cost is 154248.25.
# At epoch 7200 the mean cost is 154294.1875.
# At epoch 7300 the mean cost is 154226.3125.
# At epoch 7400 the mean cost is 154188.671875.
# At epoch 7500 the mean cost is 154198.25.
# At epoch 7600 the mean cost is 154191.640625.
# At epoch 7700 the mean cost is 154194.09375.
# At epoch 7800 the mean cost is 154206.265625.
# At epoch 7900 the mean cost is 154192.28125.
# At epoch 8000 the mean cost is 154195.5625.
# At epoch 8100 the mean cost is 154219.25.
# At epoch 8200 the mean cost is 154336.796875.
# At epoch 8300 the mean cost is 154274.59375.
# At epoch 8400 the mean cost is 154189.46875.
# At epoch 8500 the mean cost is 154201.9375.
# At epoch 8600 the mean cost is 154165.921875.
# At epoch 8700 the mean cost is 154205.3125.
# At epoch 8800 the mean cost is 154160.453125.
# At epoch 8900 the mean cost is 154159.8125.
# At epoch 9000 the mean cost is 154182.390625.
# At epoch 9100 the mean cost is 154165.5.
# At epoch 9200 the mean cost is 154207.71875.
# At epoch 9300 the mean cost is 154194.234375.
# At epoch 9400 the mean cost is 154147.0625.
# At epoch 9500 the mean cost is 154143.15625.
# At epoch 9600 the mean cost is 154173.78125.
# At epoch 9700 the mean cost is 154129.453125.
# At epoch 9800 the mean cost is 154127.421875.
# At epoch 9900 the mean cost is 154123.890625.
# At epoch 10000 the mean cost is 154125.984375.
# At epoch 10100 the mean cost is 154120.796875.
# At epoch 10200 the mean cost is 154131.75.
# At epoch 10300 the mean cost is 154158.0625.
# At epoch 10400 the mean cost is 154107.375.
# At epoch 10500 the mean cost is 154161.9375.
# At epoch 10600 the mean cost is 154125.59375.
# At epoch 10700 the mean cost is 154228.921875.
# At epoch 10800 the mean cost is 154174.59375.
# At epoch 10900 the mean cost is 154115.890625.
# At epoch 11000 the mean cost is 154121.0625.
# At epoch 11100 the mean cost is 154177.125.
# At epoch 11200 the mean cost is 154088.8125.
# At epoch 11300 the mean cost is 154102.984375.
# At epoch 11400 the mean cost is 154099.53125.
# At epoch 11500 the mean cost is 154094.75.
# At epoch 11600 the mean cost is 154176.6875.
# At epoch 11700 the mean cost is 154090.9375.
# At epoch 11800 the mean cost is 154092.421875.
# At epoch 11900 the mean cost is 154156.796875.
# At epoch 12000 the mean cost is 154134.265625.
# At epoch 12100 the mean cost is 154082.78125.
# At epoch 12200 the mean cost is 154127.140625.
# At epoch 12300 the mean cost is 154154.609375.
# At epoch 12400 the mean cost is 154145.34375.
# At epoch 12500 the mean cost is 154104.25.
# At epoch 12600 the mean cost is 154208.984375.
# At epoch 12700 the mean cost is 154137.0625.
# At epoch 12800 the mean cost is 154114.203125.
# At epoch 12900 the mean cost is 154110.765625.
# At epoch 13000 the mean cost is 154118.078125.
# At epoch 13100 the mean cost is 154103.4375.
# At epoch 13200 the mean cost is 154077.875.
# At epoch 13300 the mean cost is 154165.140625.
# At epoch 13400 the mean cost is 154318.625.
# At epoch 13500 the mean cost is 154089.828125.
# At epoch 13600 the mean cost is 154086.125.
# At epoch 13700 the mean cost is 154117.890625.
# At epoch 13800 the mean cost is 154135.140625.
# At epoch 13900 the mean cost is 154061.265625.
# At epoch 14000 the mean cost is 154323.15625.
# At epoch 14100 the mean cost is 154088.375.
# At epoch 14200 the mean cost is 154055.28125.
# At epoch 14300 the mean cost is 154076.25.
# At epoch 14400 the mean cost is 154066.65625.
# At epoch 14500 the mean cost is 154064.265625.
# At epoch 14600 the mean cost is 154091.25.
# At epoch 14700 the mean cost is 154062.84375.
# At epoch 14800 the mean cost is 154081.03125.
# At epoch 14900 the mean cost is 154056.15625.
# time elapsed= 194.75565695762634

# %%
def cost(y):
  cost1=0.0
  D1=0.0
  for i in range(ite+1):
    cost1+=D1*y[i]+(kappa/2.0)*np.power(y[i],2)
    D1=(D1+kappa*y[i])*np.exp(-rho*T/ite)
  return cost1

# %%
from torch.nn.modules.pooling import MaxPool1d
M1=10
t_test=torch.zeros([M1,1])
D_test=torch.zeros([M1,1])
#D_test=torch.FloatTensor(M,1).uniform_(0.1,0.5)   #Price impact D_t
#R_test=torch.FloatTensor(M1,1).uniform_(50,100)   #remaining balance R_t   #To get a positive solution R_t has to be greater than D_t
R_test=torch.linspace(X0*0.95, X0*1.05, steps=M1).unsqueeze(1)
kappa,rho=kappa_rho_sim(M1,ite,theta1,mu1,sigma1,theta2,mu2,sigma2)
#(M,ite,theta1,mu1,sigma1,theta2,mu2,sigma2)
x_test=torch.cat((t_test,D_test,R_test,kappa[:,0].unsqueeze(1),rho[:,0].unsqueeze(1)),dim=1)
print('Input=',x_test,'\n')
a=torch.zeros(M1,ite+1)
#print(a.shape)
for i in range(ite+1):
  if(i!=ite):
    #print(x_test)
    soln_pred=model(x_test).squeeze(1).detach()
    a[:,i]=soln_pred
    x_test=update(x_test,soln_pred,i)
    #print(x_test,'\n')
  else:
    a[:,i]=R_test.squeeze(1)-torch.sum(a,dim=1)

x1=R_test.squeeze().numpy()
c_pred=np.zeros(M1)

for i in range(M1):
  print('size of total order=',x1[i])


  print('predicted soln=',a[i,:],'sum of all execution=',torch.sum(a[i,:]).detach())
  #pred_cost=cost(a[i,:].detach().numpy())
#   print('predicted cost=',pred_cost,'\n')
# Out:
# Input= tensor([[0.0000e+00, 0.0000e+00, 9.5000e+03, 1.0000e-02, 5.0000e+00],
#         [0.0000e+00, 0.0000e+00, 9.6111e+03, 1.0000e-02, 5.0000e+00],
#         [0.0000e+00, 0.0000e+00, 9.7222e+03, 1.0000e-02, 5.0000e+00],
#         [0.0000e+00, 0.0000e+00, 9.8333e+03, 1.0000e-02, 5.0000e+00],
#         [0.0000e+00, 0.0000e+00, 9.9444e+03, 1.0000e-02, 5.0000e+00],
#         [0.0000e+00, 0.0000e+00, 1.0056e+04, 1.0000e-02, 5.0000e+00],
#         [0.0000e+00, 0.0000e+00, 1.0167e+04, 1.0000e-02, 5.0000e+00],
#         [0.0000e+00, 0.0000e+00, 1.0278e+04, 1.0000e-02, 5.0000e+00],
#         [0.0000e+00, 0.0000e+00, 1.0389e+04, 1.0000e-02, 5.0000e+00],
#         [0.0000e+00, 0.0000e+00, 1.0500e+04, 1.0000e-02, 5.0000e+00]])
#
# size of total order= 9500.0
# predicted soln= tensor([1793.6670,  738.6013,  697.8931,  693.3566,  689.0146,  684.9203,
#          680.8139,  677.1879,  673.4748,  582.3930, 1588.6772]) sum of all execution= tensor(9499.9990)
# size of total order= 9611.111
# predicted soln= tensor([1815.8639,  739.1315,  702.1917,  697.4715,  692.9067,  688.5425,
#          684.2974,  680.3007,  676.5035,  597.6511, 1636.2505]) sum of all execution= tensor(9611.1113)
# size of total order= 9722.223
# predicted soln= tensor([1838.0609,  736.7715,  706.4585,  701.6098,  696.8516,  692.4288,
#          688.2755,  684.2968,  680.5016,  645.3586, 1651.6094]) sum of all execution= tensor(9722.2227)
# size of total order= 9833.333
# predicted soln= tensor([1860.2576,  767.0560,  709.8928,  704.9609,  700.1962,  695.4566,
#          691.0204,  686.9219,  682.8693,  669.3387, 1665.3628]) sum of all execution= tensor(9833.3330)
# size of total order= 9944.444
# predicted soln= tensor([1882.4547,  757.3983,  714.3641,  709.2867,  704.2000,  699.2737,
#          694.4571,  690.0667,  685.8682,  677.2554, 1729.8193]) sum of all execution= tensor(9944.4443)
# size of total order= 10055.556
# predicted soln= tensor([1904.6516,  778.9704,  717.6760,  712.2601,  707.1660,  702.1924,
#          697.2500,  692.7167,  688.5469,  684.5010, 1769.6240]) sum of all execution= tensor(10055.5547)
# size of total order= 10166.667
# predicted soln= tensor([1926.8485,  774.9816,  722.1812,  716.8284,  711.4787,  706.3685,
#          701.4407,  696.7125,  692.2863,  687.9619, 1829.5781]) sum of all execution= tensor(10166.6660)
# size of total order= 10277.777
# predicted soln= tensor([1949.0453,  791.3866,  725.9988,  720.4207,  714.9286,  709.6345,
#          704.5036,  699.6457,  694.8466,  690.3238, 1877.0420]) sum of all execution= tensor(10277.7773)
# size of total order= 10388.889
# predicted soln= tensor([1971.2422,  813.0145,  729.2696,  723.5629,  717.9472,  712.3055,
#          706.9286,  701.7567,  696.9035,  692.2382, 1923.7197]) sum of all execution= tensor(10388.8887)
# size of total order= 10500.0
# predicted soln= tensor([1993.4391,  810.4188,  733.6314,  727.7166,  721.7486,  715.8926,
#          710.4157,  705.1799,  700.3086,  695.6481, 1985.6006]) sum of all execution= tensor(10500.0010)

# %%
p_soln=a.numpy()
t_step=np.linspace(0,ite,num=ite+1)
#name='E:/Robin research/7thECMF_PosterPresent/Figures/N.eps'
def plotting(t):
  #print('Total order size=',x1[t],np.sum(n_soln[t]),np.sum(p_soln[t]))
  #print(n_soln[t],p_soln[t])
  plt.figure(figsize=(6,3))
  #plt.bar(t_step,t_soln[t],color='blue',width=0.3,label='Closed-Form')
  plt.bar(t_step,p_soln[t],color='red',width=0.2)
  #plt.bar(t_step,n_soln[t],color='green',width=0.1,label='numeric')
  plt.title('Total Order size X= %f' % (x1[t]))
  plt.xlabel('Time steps')
  plt.ylabel('Optimal orders')
  #plt.legend()

#   #plt.savefig('f.eps', format='eps')
#   if(t==0):
#     plt.savefig(name,format='eps')      
  plt.show()
for i in range(0,M1,3):
  plotting(i)

# %%
print(kappa)
# Out:
# tensor([[0.0100, 0.0100, 0.0103, 0.0104, 0.0105, 0.0106, 0.0108, 0.0108, 0.0110,
#          0.0109, 0.0109],
#         [0.0100, 0.0102, 0.0104, 0.0105, 0.0106, 0.0108, 0.0109, 0.0110, 0.0112,
#          0.0111, 0.0111],
#         [0.0100, 0.0103, 0.0106, 0.0106, 0.0108, 0.0108, 0.0108, 0.0107, 0.0108,
#          0.0108, 0.0109],
#         [0.0100, 0.0100, 0.0100, 0.0102, 0.0102, 0.0104, 0.0106, 0.0105, 0.0107,
#          0.0109, 0.0109],
#         [0.0100, 0.0103, 0.0104, 0.0105, 0.0106, 0.0109, 0.0110, 0.0110, 0.0111,
#          0.0111, 0.0111],
#         [0.0100, 0.0101, 0.0103, 0.0105, 0.0106, 0.0107, 0.0109, 0.0109, 0.0109,
#          0.0110, 0.0110],
#         [0.0100, 0.0103, 0.0103, 0.0104, 0.0106, 0.0107, 0.0107, 0.0109, 0.0109,
#          0.0110, 0.0111],
#         [0.0100, 0.0102, 0.0102, 0.0103, 0.0105, 0.0105, 0.0106, 0.0107, 0.0109,
#          0.0110, 0.0109],
#         [0.0100, 0.0100, 0.0102, 0.0104, 0.0106, 0.0107, 0.0110, 0.0111, 0.0112,
#          0.0113, 0.0114],
#         [0.0100, 0.0102, 0.0104, 0.0106, 0.0107, 0.0110, 0.0111, 0.0111, 0.0111,
#          0.0111, 0.0112]])

# %%
print(rho)
# Out:
# tensor([[5.0000, 5.0012, 5.0038, 5.0054, 5.0065, 5.0080, 5.0076, 5.0099, 5.0090,
#          5.0099, 5.0118],
#         [5.0000, 5.0028, 5.0047, 5.0058, 5.0066, 5.0082, 5.0075, 5.0082, 5.0099,
#          5.0091, 5.0090],
#         [5.0000, 5.0028, 5.0041, 5.0061, 5.0075, 5.0094, 5.0110, 5.0110, 5.0112,
#          5.0125, 5.0135],
#         [5.0000, 5.0031, 5.0040, 5.0041, 5.0041, 5.0040, 5.0064, 5.0086, 5.0089,
#          5.0092, 5.0096],
#         [5.0000, 5.0030, 5.0044, 5.0065, 5.0075, 5.0094, 5.0090, 5.0099, 5.0108,
#          5.0121, 5.0126],
#         [5.0000, 5.0000, 5.0025, 5.0024, 5.0044, 5.0062, 5.0059, 5.0062, 5.0086,
#          5.0104, 5.0119],
#         [5.0000, 5.0005, 5.0013, 5.0034, 5.0058, 5.0082, 5.0081, 5.0101, 5.0121,
#          5.0128, 5.0124],
#         [5.0000, 5.0027, 5.0045, 5.0045, 5.0066, 5.0064, 5.0060, 5.0070, 5.0074,
#          5.0071, 5.0064],
#         [5.0000, 5.0013, 5.0032, 5.0053, 5.0077, 5.0071, 5.0085, 5.0084, 5.0094,
#          5.0091, 5.0105],
#         [5.0000, 5.0025, 5.0043, 5.0064, 5.0064, 5.0064, 5.0086, 5.0089, 5.0095,
#          5.0092, 5.0089]])

# %%
# torch.save(model, 'LOB_stoc_N10.pth')
